# %%
#importing libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('/content/Women_Frailty.csv')  #reading the dataset and printing it.

# %%
df.head()
# Out:
#    Height  Weight  Age  Grip Strength  Frailty    BMI  Grip Strength (lbs)  \
# 0    65.8     112   30             30      NaN  18.19                66.14
# 1    71.5     136   19             31      NaN  18.70                68.34
# 2    69.4     153   45             29      NaN  22.33                63.93
# 3    68.2     142   22             28      NaN  21.46                61.73
# 4    67.8     144   29             24      NaN  22.02                52.91
#
#    Frailty Index
# 0          35.34
# 1          19.54
# 2          39.21
# 3          20.13
# 4          24.31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Height               10 non-null     float64
#  1   Weight               10 non-null     int64
#  2   Age                  10 non-null     int64
#  3   Grip Strength        10 non-null     int64
#  4   Frailty              0 non-null      float64
#  5   BMI                  10 non-null     float64
#  6   Grip Strength (lbs)  10 non-null     float64
#  7   Frailty Index        10 non-null     float64
# dtypes: float64(5), int64(3)
# memory usage: 772.0 bytes

# %%
df.columns # printing the column names
# Out:
# Index(['Height', 'Weight', 'Age', 'Grip Strength', 'Frailty', 'BMI',
#        'Grip Strength (lbs)', 'Frailty Index'],
#       dtype='object')

# %%
df.nunique() # checking the unique values
# Out:
# Height                 10
# Weight                  8
# Age                    10
# Grip Strength           9
# Frailty                 0
# BMI                    10
# Grip Strength (lbs)     9
# Frailty Index          10
# dtype: int64

# %%
df.isnull().sum() #checking the null values
# Out:
# Height                  0
# Weight                  0
# Age                     0
# Grip Strength           0
# Frailty                10
# BMI                     0
# Grip Strength (lbs)     0
# Frailty Index           0
# dtype: int64

# %%
df.to_csv('cleaned_data.csv', index=False) # saving the cleaned data file.
